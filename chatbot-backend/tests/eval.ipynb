# %%
import pandas as pd

# Đọc file CSV với encoding utf-16
df = pd.read_csv(r'C:\Users\mt200\OneDrive\Desktop\AI_egineering\FinalBlogChatbot\chatbot-backend\src\eval.csv', encoding='utf-16')

# %%
df
# Out:
#                                      chỉ số bmi là gì  \
# 0   hãy tính chỉ số bmi của tôi và tôi nên có chế ...
# 1   Trong khoa học tâm lý, chất lượng giấc ngủ thấ...
# 2   Trong tâm lý học, PFA-S là gì và tại sao cần P...
# 3   Trong tâm lý học, nêu các bước hỗ trợ các vấn ...
# 4   Hãy tư vấn hỗ trợ  nghiện mạng, nghiện game ch...
# ..                                                ...
# 71        Bệnh suy thận có biểu hiện và ảnh hưởng gì?
# 72                Trái cây nào tốt cho sức khỏe nhât?
# 73    Tôi bị béo phì thì nên tránh những thức ăn nào?
# 74                    Không ăn cá thì có bị gì không?
# 75          ăn nhieu chất béo ảnh hưởng gì đến cơ thể
#
#    ['1. Chỉ số BMI là gì?', '2. BMI là viết tắt của chỉ số gì?', '3. Giải thích về chỉ số BMI trong sức khỏe.']  \
# 0   ['1. Tính chỉ số BMI của tôi và gợi ý chế độ ă...
# 1   ['1. Các biểu hiện của chất lượng giấc ngủ kém...
# 2   ['1. PFA-S trong tâm lý học là gì và lý do cần...
# ...

# %%
df.columns = ['question', 'similar_question', '', 'time']

# %%
# Xóa cột 'Tên Cột' khỏi DataFrame
df = df.drop(columns=[''])

# %%
df
# Out:
#                                              question  \
# 0   hãy tính chỉ số bmi của tôi và tôi nên có chế ...
# 1   Trong khoa học tâm lý, chất lượng giấc ngủ thấ...
# 2   Trong tâm lý học, PFA-S là gì và tại sao cần P...
# 3   Trong tâm lý học, nêu các bước hỗ trợ các vấn ...
# 4   Hãy tư vấn hỗ trợ  nghiện mạng, nghiện game ch...
# ..                                                ...
# 71        Bệnh suy thận có biểu hiện và ảnh hưởng gì?
# 72                Trái cây nào tốt cho sức khỏe nhât?
# 73    Tôi bị béo phì thì nên tránh những thức ăn nào?
# 74                    Không ăn cá thì có bị gì không?
# 75          ăn nhieu chất béo ảnh hưởng gì đến cơ thể
#
#                                      similar_question       time
# 0   ['1. Tính chỉ số BMI của tôi và gợi ý chế độ ă...  11.257396
# 1   ['1. Các biểu hiện của chất lượng giấc ngủ kém...   4.648397
# 2   ['1. PFA-S trong tâm lý học là gì và lý do cần...   5.716729
# ...

# %%
mean_time=df['time'].mean()

# %%
mean_time
# Out:
# 4.461306857435327

# %%
import pandas as pd

# Đọc file CSV với encoding utf-16
df_tools = pd.read_csv(r'C:\Users\mt200\OneDrive\Desktop\AI_egineering\FinalBlogChatbot\chatbot-backend\src\tools_log.csv', encoding='utf-16')

# %%
df_tools
# Out:
#                                        chỉ số bmi là gì
# 0                  RetrieveLifeBloodTool,"1. Chỉ số BMI
# 1     [**Chỉ số BMI**](https://www.vinmec.com/vie/ba...
# 2     binh-thuong-vi) (Body Mass Index) được gọi là ...
# 3     số giúp đánh giá cơ thể đang thuộc tình trạng ...
# 4     hay béo phì. Theo đó, **chỉ số BMI** được tính...
# ...                                                 ...
# 7402  protein (như thịt đỏ) thường chứa nhiều chất b...
# 7403  ăn này có thể làm tăng lượng chất béo bão hòa ...
# 7404                   ________________________________
# 7405                                         Chú thích:
# 7406  (*) Cơ thể chỉ dự trữ chất béo. (Nguồn: https:...
#
# [7407 rows x 1 columns]

# %%
# Cấu hình số dòng và cột tối đa hiển thị
pd.set_option('display.max_rows', 150)  # Hiển thị tối đa 100 dòng

# %%
question=df["question"]
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
context=[""]
