# %%
urls = [
	"https://www.vinmec.com/vie/bai-viet/cac-chi-so-khoi-luong-co-gom-nhung-gi-vi",
	"https://tamanhhospital.vn/chi-so-xet-nghiem-cong-thuc-mau/",
	"https://medlatec.vn/tin-tuc/cam-nang-suc-khoe-thoi-diem-nao-nen-kham-suc-khoe-dinh-ky-s150-n28812?gidzl=b1SHL0tBmnAJ2nDM3TF54fC5458GtSOPYG553nRRb4I31qLL7zsLGj454LL4ty53smD4KJEjxk5p2it55m",
	"https://vnexpress.net/che-do-an-giam-can-phu-hop-chi-so-bmi-3268100.html",
	"https://www.workoutbythao.com/post/che-do-an-uong-luyen-tap-nhu-the-nao-de-co-chi-so-bmi-ly-tuong-101"
]

titles = [
	"Chỉ số cơ thể",
	"Chỉ số xét nghiệm máu",
	"Khám định kì",
	"Chế độ giảm cân phù hợp với chỉ số BMI",
	"Chế độ ăn uống luyện tập như thế nào để có chỉ số BMI lý tưởng"

]

# %%
from llama_index.readers.web import FireCrawlWebReader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from llama_index.readers.web import FireCrawlWebReader
#
# ModuleNotFoundError: No module named 'llama_index.readers.web'

# %%
from llama_index.readers.web import FireCrawlWebReader
from llama_index.core import SummaryIndex
import os


# Initialize FireCrawlWebReader to crawl a website
firecrawl_reader = FireCrawlWebReader(
    api_key="fc-983369ae77e342da872a1edb0f6b70b9",  # Replace with your actual API key from https://www.firecrawl.dev/
    mode="scrape",  # Choose between "crawl" and "scrape" for single page scraping
    params={"additional": "parameters"}  # Optional additional parameters
)

# Set the environment variable for the virtual key
#os.environ["OPENAI_API_KEY"] = "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"

# Load documents from a single page URL
documents = firecrawl_reader.load_data(url="https://www.vinmec.com/vie/bai-viet/cac-chi-so-khoi-luong-co-gom-nhung-gi-vi")
index = SummaryIndex.from_documents(documents)

# Set Logging to DEBUG for more detailed outputs
# query_engine = index.as_query_engine()
# response = query_engine.query("What did the author do growing up?")
# display(Markdown(f"<b>{response}</b>"))

# %%
documents[0]
# Out:
# Document(id_='2b526bd0-3224-4aa8-a819-ed598558664d', embedding=None, metadata={'title': 'Các chỉ số khối lượng cơ thể gồm những gì? | Vinmec', 'description': 'Các chỉ số khối lượng cơ thể giúp đánh giá tỷ lệ các thành phần cơ thể, qua đó phản ánh tình trạng sức khỏe cũng như sự thay đổi của cơ thể khi bạn đang ăn kiêng hoặc luyện tập các môn thể thao. Các chỉ số khối lượng cơ thể gồm các chỉ số cơ bản như khối lượng cơ thể, chiều cao, chỉ số BMI, bề dày lớp mỡ dưới da,...', 'favicon': 'https://www.vinmec.com/assets/images/favicons/favicon.81b1c31dad6a.ico', 'language': 'vi', 'robots': 'max-image-preview:large,index,follow', 'ogTitle': 'Các chỉ số khối lượng cơ thể gồm những gì?', 'ogUrl': 'https://www.vinmec.com/vie/bai-viet/cac-chi-so-khoi-luong-co-gom-nhung-gi-vi', 'ogImage': 'https://www.vinmec.com/static/uploads/20191127_084023_509719_bmi_max_1800x1800_jpg_145884ca6b.jpg', 'ogLocaleAlternate': [], 'ogSiteName': 'Vinmec International Hospital', 'scrapeId': 'abda8806-bcbc-4121-9c09
# ...

# %%
# Set Logging to DEBUG for more detailed outputs
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from IPython.display import Markdown
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Chỉ số BMI là một trong các chỉ số khối lượng cơ thể cơ bản, giúp đánh giá tỷ lệ giữa cân nặng và chiều cao của một người để đánh giá tình trạng cơ thể, phản ánh sự thay đổi khi ăn kiêng hoặc luyện tập thể dục.</b>

# %%
print(response.get_formatted_sources())
# Out:
# > Source (Doc id: b39ee93d-6b80-49a1-b288-4c37780ffc06): - [Tìm bác sĩ](https://www.vinmec.com/vie/chuyen-gia-y-te/)
# - [Khóa học trực tuyến](https://songk...
#
# > Source (Doc id: 0654afad-e1cf-4230-b748-f8240040a277): - [Cấp cứu](https://www.vinmec.com/vie/chuyen-khoa/cap-cuu)
# - [Trung tâm Tim mạch](https://www.vi...
#
# > Source (Doc id: fd3def4a-03b8-4809-a5fb-8a5a6a72bb4a): vinmec.com/vie/chuyen-khoa/tieu-hoa-gan-mat/)
# - [Trung tâm Nhi](https://www.vinmec.com/vie/chuyen...
#
# > Source (Doc id: d832f1ee-0896-4308-bf91-cbe403a87a10): vinmec.com/vie/chuyen-khoa/trung-tam-mat-vinmec-alina/)
#
# - [Nha khoa Vinmec View Premium](https:/...
#
# > Source (Doc id: 298a5905-de45-4ccd-a699-6de9d50bc3b2): vinmec.com/vie/chuyen-khoa/chan-thuong-chinh-hinh-y-hoc-the-thao/)
# - [Viện nghiên cứu tế bào gốc ...
#
# > Source (Doc id: 7f808f36-e599-4251-a1b0-4dc085153979): vinmec.com/vie/chuyen-khoa/vien-nghien-cuu-te-bao-goc-va-cong-nghe-gen/)
# - [Trung tâm Vacxin](htt...
#
# ...

# %%
# Load documents from a single page URL
documents = firecrawl_reader.load_data(url="http://paulgraham.com/")

# %%
documents[0]

# %%
index = SummaryIndex.from_documents(documents)

# %%
# set Logging to DEBUG for more detailed outputs
query_engine = index.as_query_engine()
response = query_engine.query("What did the author do growing up?")

# %%
# set Logging to DEBUG for more detailed outputs
query_engine = index.as_query_engine()
response = query_engine.query("What did the author do growing up?")

# %%
from bs4 import BeautifulSoup
import requests

# Step 1: Fetch the webpage
url = "https://www.vinmec.com/vie/bai-viet/cac-chi-so-khoi-luong-co-gom-nhung-gi-vi"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="vi">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0,viewport-fit=cover" name="viewport"/>
# <meta content="max-image-preview:large,index,follow" name="robots"/>
# <meta content="#0077aa" name="theme-color"/>
# <meta content="12d20ce054669180" name="yandex-verification"/>
# <title>Các chỉ số khối lượng cơ thể gồm những gì? | Vinmec</title>
# <meta content="Các chỉ số khối lượng cơ thể giúp đánh giá tỷ lệ các thành phần cơ thể, qua đó phản ánh tình trạng sức khỏe cũng như sự thay đổi của cơ thể khi bạn đang ăn kiêng hoặc luyện tập các môn thể thao. Các chỉ số khối lượng cơ thể gồm các chỉ số cơ bản như khối lượng cơ thể, chiều cao, chỉ số BMI, bề dày lớp mỡ dưới da,..." name="description"/>
# <link href="https://www.vinmec.com/vie/bai-viet/cac-chi-so-khoi-luong-co-gom-nhung-gi-vi" rel="canonical"/>
# <meta content="Các chỉ số khối lượng cơ thể gồm những gì?" property="og:title"/>
# ...

# %%
# Step 2: Select the main content
title = soup.select_one(".post-detail")  # Use a single CSS selector
print(title.prettify())
# Out:
# <div class="post-detail">
#  <div class="post-header mb2">
#   <div class="col-8 px2">
#    <h1 class="single-title single-title-line">
#     Các chỉ số khối lượng cơ thể gồm những gì?
#    </h1>
#   </div>
#   <div class="col-4 sidebar px2">
#    <div class="expert-consultation" style="padding-left: 10px">
#     <span class="expert-thumbnail left">
#      <a href="/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi">
#       <img alt="Nguyễn Thị Ngọc" loading="lazy" src="/static/uploads/thumbnail_NGUYEN_THI_NGOC_1f0bf3997e.jpg">
#       </img>
#      </a>
#     </span>
#     <div class="expert-content">
#      <p class="text-position">
#       Thạc sĩ,  Bác sĩ chuyên khoa II,
#      </p>
#      <p class="name">
#       <a href="/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi">
#        <span>
#         Nguyễn Thị Ngọc
#        </span>
#       </a>
#      </p>
#     </div>
#    </div>
#   </div>
#   <div class="col-8 px2">
#   </div>
#  </div>
# </div>

# %%
# Step 2: Select the main content
main_content = soup.select_one(".entry")  # Target the main-col section
target_words = ["Để đặt lịch khám tại viện"] 
if main_content:
    # Find all elements with the class 'relate-video' inside main-col
    for p_tag in main_content.find_all("p"):
        if any(word in p_tag.get_text() for word in target_words):
            p_tag.decompose()  # Remove the <p> tag from the HTML
        
    for element in main_content.select(".relate-video"):
        print("--------------------")
        print(element.prettify())
        print("--------------------")
        element.decompose()
    # Print the modified HTML
    print(main_content.prettify())
else:
    print("No main content found.")
# Out:
# --------------------
# <div class="relate-video">
#  <iframe allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen="" class="embed-video" frameborder="0" loading="lazy" referrerpolicy="strict-origin-when-cross-origin" src="https://www.youtube.com/embed/j6iuGkKEqek" title="YouTube video player">
#  </iframe>
#  <a class="video-title" href="https://www.youtube.com/watch?v=j6iuGkKEqek" rel="nofollow">
#   <span>
#    Khám sức khỏe định kỳ có ý nghĩa như thế nào trong việc dự phòng bệnh tật?
#   </span>
#  </a>
# </div>
#
# --------------------
# <div class="entry" id="main-article">
#  <p>
#   <b>
#    Bài viết được tư vấn chuyên môn bởi Thạc sĩ, Bác sĩ Nguyễn Thị Ngọc - Bác sĩ Nội tổng quát - Nội tiết -
#   </b>
#   <a href="https://www.vinmec.com/vie/bai-viet/kham-suc-khoe-tong-quat-nu-la-kham-nhung-gi-vi">
#    <b>
#     Khoa Khám bệnh &amp; Nội khoa - Bệnh viện Đa khoa Quốc tế Vinmec Central Park
#    </b>
# ...

# %%
if title and main_content:
    combined_div = soup.new_tag("div", attrs={"class": "main-content"})
    # Add main-col and main-post content
    combined_div.append(title)
    combined_div.append(main_content)
else:
    print("Either .main-col or .main-post not found.")
print(combined_div)
# Out:
# <div class="main-content"><div class="post-detail">
# <div class="post-header mb2">
# <div class="col-8 px2">
# <h1 class="single-title single-title-line">Các chỉ số khối lượng cơ thể gồm những gì?</h1>
# </div>
# <div class="col-4 sidebar px2">
# <div class="expert-consultation" style="padding-left: 10px">
# <span class="expert-thumbnail left">
# <a href="/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi">
# <img alt="Nguyễn Thị Ngọc" loading="lazy" src="/static/uploads/thumbnail_NGUYEN_THI_NGOC_1f0bf3997e.jpg">
# </img></a>
# </span>
# <div class="expert-content">
# <p class="text-position">
#
#                Thạc sĩ,  Bác sĩ chuyên khoa II,
#
#             </p>
# <p class="name">
# <a href="/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi"><span>Nguyễn Thị Ngọc</span></a>
# </p>
# </div>
# </div>
# </div>
# <div class="col-8 px2">
# </div>
# </div>
# </div><div class="entry" id="main-article">
# ...

# %%
combined_div
# Out:
# <div class="main-content"><div class="post-detail">
# <div class="post-header mb2">
# <div class="col-8 px2">
# <h1 class="single-title single-title-line">Các chỉ số khối lượng cơ thể gồm những gì?</h1>
# </div>
# <div class="col-4 sidebar px2">
# <div class="expert-consultation" style="padding-left: 10px">
# <span class="expert-thumbnail left">
# <a href="/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi">
# <img alt="Nguyễn Thị Ngọc" loading="lazy" src="/static/uploads/thumbnail_NGUYEN_THI_NGOC_1f0bf3997e.jpg">
# </img></a>
# </span>
# <div class="expert-content">
# <p class="text-position">
#
#                Thạc sĩ,  Bác sĩ chuyên khoa II,
#
#             </p>
# <p class="name">
# <a href="/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi"><span>Nguyễn Thị Ngọc</span></a>
# </p>
# </div>
# </div>
# </div>
# <div class="col-8 px2">
# </div>
# </div>
# </div><div class="entry" id="main-article">
# ...

# %%
with open("combined_content.html", "w", encoding="utf-8") as file:
    file.write(str(combined_div))

# %%
pip install html2text
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# 'DOSKEY' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pip install markdownify
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting markdownify
# ...
# 'DOSKEY' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import html2text
from datetime import datetime


# Step 1: Convert HTML to Markdown
def html_to_markdown(html_content):
    markdown_converter = html2text.HTML2Text()
    markdown_converter.ignore_links = False  # Keep links
    markdown_content = markdown_converter.handle(html_content)
    return markdown_content

# Step 2: Add Custom Metadata
def add_metadata(markdown_content, metadata):
    metadata_string = "\n".join([f"{key}: {value}" for key, value in metadata.items()])
    return f"---\n{metadata_string}\n---\n\n{markdown_content}"

# Step 3: Chunk the Content
def chunk_content(content, chunk_size=300):
    chunks = []
    lines = content.split("\n")
    chunk = []
    word_count = 0

    for line in lines:
        words = line.split()
        word_count += len(words)
        chunk.append(line)

        if word_count >= chunk_size:
            chunks.append("\n".join(chunk))
            chunk = []
            word_count = 0

    if chunk:
        chunks.append("\n".join(chunk))

    return chunks



# Example Usage
if __name__ == "__main__":
    # Metadata
    metadata = {
        "title": "Các chỉ số khối lượng cơ thể",
        "author": "Nguyễn Thị Ngọc",
        "date": datetime.now().strftime("%Y-%m-%d"),
        "link": "https://www.vinmec.com/vie/bai-viet/cac-chi-so-khoi-luong-co-gom-nhung-gi-vi",
        "tags": ["health", "medical","IBM"]
    }

    # Convert HTML to Markdown and Add Metadata
    markdown_content = html_to_markdown(str(combined_div))
    print(markdown_content)
    content_with_metadata = add_metadata(markdown_content, metadata)

    print(content_with_metadata)
# Out:
# # Các chỉ số khối lượng cơ thể gồm những gì?
#
# [ ![Nguyễn Thị Ngọc](/static/uploads/thumbnail_NGUYEN_THI_NGOC_1f0bf3997e.jpg)
# ](/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi)
#
# Thạc sĩ, Bác sĩ chuyên khoa II,
#
# [Nguyễn Thị Ngọc](/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi)
#
# **Bài viết được tư vấn chuyên môn bởi Thạc sĩ, Bác sĩ Nguyễn Thị Ngọc - Bác sĩ
# Nội tổng quát - Nội tiết -** [**Khoa Khám bệnh & Nội khoa - Bệnh viện Đa khoa
# Quốc tế Vinmec Central Park**](https://www.vinmec.com/vie/bai-viet/kham-suc-
# khoe-tong-quat-nu-la-kham-nhung-gi-vi)**.**
#
# **Các chỉ số khối lượng cơ thể giúp đánh giá tỷ lệ các thành phần cơ thể, qua
# đó phản ánh tình trạng sức khỏe cũng như sự thay đổi của cơ thể khi bạn đang
# ăn kiêng hoặc luyện tập các môn thể thao. Các chỉ số khối lượng cơ thể gồm các
# chỉ số cơ bản như khối lượng cơ thể, chiều cao, chỉ số BMI, bề dày lớp mỡ dưới
# da,...**
#
# ## 1\. Chỉ số khối lượng cơ thể
#
# ...

# %%
from llama_index.core.schema import Document
# Create a Document with the content and metadata
document = Document(text=markdown_content, metadata=metadata)

# %%
from llama_index.core.extractors import (
    TitleExtractor,
    QuestionsAnsweredExtractor,
)
from llama_index.core.node_parser import TokenTextSplitter

text_splitter = TokenTextSplitter(
    separator=" ", chunk_size=512, chunk_overlap=128
)
title_extractor = TitleExtractor(nodes=5)
qa_extractor = QuestionsAnsweredExtractor(questions=3)

# assume documents are defined -> extract nodes
from llama_index.core.ingestion import IngestionPipeline

pipeline = IngestionPipeline(
    transformations=[text_splitter, title_extractor, qa_extractor]
)

nodes = pipeline.run(
    documents=markdown_content,
    in_place=True,
    show_progress=True,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 20
#      14 from llama_index.core.ingestion import IngestionPipeline
#      16 pipeline = IngestionPipeline(
#      17     transformations=[text_splitter, title_extractor, qa_extractor]
#      18 )
# ---> 20 nodes = pipeline.run(
#      21     documents=markdown_content,
#      22     in_place=True,
#      23     show_progress=True,
#      24 )
#
# File c:\Users\mt200\OneDrive\Desktop\AI_egineering\FinalBlogChatbot\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
# ...

# %%
from llama_index.core import Document
from llama_index.core.schema import MetadataMode

document = Document(
    text=markdown_content,
    metadata={
        "category": "Chỉ số cơ thể",
        "author": "Nguyễn Thị Ngọc",
    },
    excluded_llm_metadata_keys=["file_name"],
    metadata_seperator="::",
    metadata_template="{key}=>{value}",
    text_template="Metadata: {metadata_str}\n-----\nContent: {content}",
)

print(
    "The LLM sees this: \n",
    document.get_content(metadata_mode=MetadataMode.LLM),
)
print(
    "The Embedding model sees this: \n",
    document.get_content(metadata_mode=MetadataMode.EMBED),
)
# Out:
# The LLM sees this:
#  Metadata: category=>Chỉ số cơ thể::author=>Nguyễn Thị Ngọc
# -----
# Content: # Các chỉ số khối lượng cơ thể gồm những gì?
#
# [ ![Nguyễn Thị Ngọc](/static/uploads/thumbnail_NGUYEN_THI_NGOC_1f0bf3997e.jpg)
# ](/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi)
#
# Thạc sĩ, Bác sĩ chuyên khoa II,
#
# [Nguyễn Thị Ngọc](/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi)
#
# **Bài viết được tư vấn chuyên môn bởi Thạc sĩ, Bác sĩ Nguyễn Thị Ngọc - Bác sĩ
# Nội tổng quát - Nội tiết -** [**Khoa Khám bệnh & Nội khoa - Bệnh viện Đa khoa
# Quốc tế Vinmec Central Park**](https://www.vinmec.com/vie/bai-viet/kham-suc-
# khoe-tong-quat-nu-la-kham-nhung-gi-vi)**.**
#
# **Các chỉ số khối lượng cơ thể giúp đánh giá tỷ lệ các thành phần cơ thể, qua
# đó phản ánh tình trạng sức khỏe cũng như sự thay đổi của cơ thể khi bạn đang
# ăn kiêng hoặc luyện tập các môn thể thao. Các chỉ số khối lượng cơ thể gồm các
# chỉ số cơ bản như khối lượng cơ thể, chiều cao, chỉ số BMI, bề dày lớp mỡ dưới
# ...

# %%
documents=[document]

# %%
pip install nest_asyncio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# 'DOSKEY' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import openai

openai.api_key = "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"

# %%
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt="Hello, how are you?",
    max_tokens=5
)

print(response)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 response = openai.Completion.create(
#       2     engine="text-davinci-003",
#       3     prompt="Hello, how are you?",
#       4     max_tokens=5
#       5 )
#       7 print(response)
#
# File c:\Users\mt200\OneDrive\Desktop\AI_egineering\FinalBlogChatbot\.venv\Lib\site-packages\openai\lib\_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.Completion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# ...

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(
    model="gpt-4o-mini",
)

# %%
llm = OpenAI(model="gpt-3.5-turbo", temperature=0.1)

# %%
llm = OpenAI(api_key="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")

# %%
resp = llm.complete("Paul Graham is ")

# %%
print(resp)
# Out:
# Paul Graham is an influential computer scientist, entrepreneur, and venture capitalist, best known for his work in the field of programming languages and for co-founding the startup accelerator Y Combinator. He is also a prominent essayist, having written extensively on topics related to startups, technology, and entrepreneurship. Graham is known for his advocacy of Lisp programming language and has contributed to its development. His essays often provide insights into the startup ecosystem, innovation, and the challenges faced by entrepreneurs. Additionally, he has been involved in various successful startups and has invested in numerous companies through Y Combinator, which has helped launch many well-known tech companies.

# %%
from llama_index.core.extractors import (
    TitleExtractor,
    QuestionsAnsweredExtractor,
)
from llama_index.core.node_parser import TokenTextSplitter

text_splitter = TokenTextSplitter(
    separator=" ", chunk_size=512, chunk_overlap=128
)
title_extractor = TitleExtractor(nodes=5, llm=llm)
qa_extractor = QuestionsAnsweredExtractor(questions=3, llm=llm)

# assume documents are defined -> extract nodes
from llama_index.core.ingestion import IngestionPipeline

pipeline = IngestionPipeline(
    transformations=[text_splitter, title_extractor, qa_extractor]
)

nodes = pipeline.run(
    documents=documents,
    in_place=True,
    show_progress=True,
)
# Out:
# Parsing nodes: 100%|██████████| 1/1 [00:00<00:00, 21.59it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 5/5 [00:03<00:00,  1.55it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 11/11 [00:12<00:00,  1.12s/it]

# %%
nodes[0].metadata
# Out:
# {'file_name': 'super_secret_document.txt',
#  'category': 'Chỉ số cơ thể',
#  'author': 'Nguyễn Thị Ngọc',
#  'document_title': '**"Hướng Dẫn Toàn Diện Về Chỉ Số Khối Lượng Cơ Thể: Tính Toán, Duy Trì và Ngăn Ngừa Bệnh Tật"**',
# ...

# %%
pip install llama_index.extractors
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'DOSKEY' is not recognized as an internal or external command,
# operable program or batch file.
# ERROR: Could not find a version that satisfies the requirement llama_index.extractors (from versions: none)
# ERROR: No matching distribution found for llama_index.extractors

# %%
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.extractors import (
    SummaryExtractor,
    QuestionsAnsweredExtractor,
    TitleExtractor,
    KeywordExtractor,
)

transformations = [
    SentenceSplitter(),
    TitleExtractor(nodes=5),
    QuestionsAnsweredExtractor(questions=3),
    SummaryExtractor(summaries=["prev", "self"]),
    KeywordExtractor(keywords=10),
]

# %%
from llama_index.core.ingestion import IngestionPipeline

pipeline = IngestionPipeline(transformations=transformations)

nodes = pipeline.run(documents=documents)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[116], line 5
#       1 from llama_index.core.ingestion import IngestionPipeline
#       3 pipeline = IngestionPipeline(transformations=transformations)
# ----> 5 nodes = pipeline.run(documents=documents)
#
# File c:\Users\mt200\OneDrive\Desktop\AI_egineering\FinalBlogChatbot\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# ...

# %%
from bs4 import BeautifulSoup
import requests

# Step 1: Fetch the webpage
url = "https://tamanhhospital.vn/chi-so-xet-nghiem-cong-thuc-mau/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
import pandas as pd
tables = soup.find_all("table")
tables
# Out:
# [<table border="1" cellpadding="10px" style="height: 1105px; width: 99.375%;">
#  <tbody>
#  <tr>
#  <td style="text-align: center;"><strong>STT</strong></td>
#  <td style="text-align: center;"><strong>TÊN CHỈ SỐ</strong></td>
#  <td style="text-align: center;"><strong>CHỈ SỐ BÌNH THƯỜNG</strong></td>
#  </tr>
#  <tr>
#  <td style="text-align: center;">1</td>
#  <td style="text-align: center;"><strong>WBC</strong></td>
#  <td style="text-align: center;">4 – 10 G/L</td>
#  </tr>
#  <tr>
#  <td style="text-align: center;">2</td>
#  <td style="text-align: center;"><strong>LYM</strong></td>
#  <td style="text-align: center;">17% – 48%
#  <p>hoặc 1 – 5 G/L</p></td>
#  </tr>
#  <tr>
#  <td style="text-align: center;">3</td>
#  <td style="text-align: center;"><strong>NEU</strong></td>
#  <td style="text-align: center;">43% – 76 %
#  <p>hoặc 2 – 8 G/L</p></td>
#  </tr>
#  <tr>
#  <td style="text-align: center;">4</td>
#  <td style="text-align: center;"><strong>MONO</strong></td>
# ...

# %%
response=llm.complete("Tôi có bảng html sau về chỉ số thông máu thông thường của người: \n"+str(tables[0]) + "\n\n tôi muốn bạn phân tích bảng này. Chỉ số từ bao nhiêu đến bao nhiêu là bình thường đối với mỗi thành phần, và ứng với nam và nữ chỉ số này sẽ khác nhau như thế nào?")

# %%
response.text
# Out:
# 'Dưới đây là phân tích các chỉ số thông máu trong bảng mà bạn đã cung cấp, bao gồm các khoảng giá trị bình thường cho từng thành phần và sự khác biệt giữa nam và nữ khi có:\n\n1. **WBC (Bạch cầu)**\n   - Chỉ số bình thường: 4 – 10 G/L\n\n2. **LYM (Bạch cầu lympho)**\n   - Chỉ số bình thường: 17% – 48% hoặc 1 – 5 G/L\n\n3. **NEU (Bạch cầu trung tính)**\n   - Chỉ số bình thường: 43% – 76% hoặc 2 – 8 G/L\n\n4. **MONO (Bạch cầu đơn nhân)**\n   - Chỉ số bình thường: 4% – 8% hoặc 0,2 – 1,5 G/L\n\n5. **EOS (Bạch cầu ái toan)**\n   - Chỉ số bình thường: 2% – 4% hoặc 0,1 – 0,7 G/L\n\n6. **BASO (Bạch cầu ái kiềm)**\n   - Chỉ số bình thường: 0% – 1% hoặc 0.01 – 0,25 G/L\n\n7. **RBC (Hồng cầu)**\n   - Nam: 4,5 – 5,8 T/L\n   - Nữ: 3,9 – 5,2 T/L\n\n8. **HGB (Hemoglobin)**\n   - Nam: 130 – 180 g/L\n   - Nữ: 120 – 165 g/L\n\n9. **HCT (Hematocrit)**\n   - Nam: 0,39 – 0,49 L/L\n   - Nữ: 0,33 – 0,43 L/L\n\n10. **MCV (Thể tích trung bình hồng cầu)**\n    - Chỉ số bình thường: 85 – 95 fL\n\n11. **MCH (Nồ
# ...

# %%
for table in tables:
    rows = table.find_all("tr")
    for row in rows:
        cells = row.find_all(["td", "th"])
        print(" | ".join(cell.get_text(strip=True) for cell in cells))
# Out:
# STT | TÊN CHỈ SỐ | CHỈ SỐ BÌNH THƯỜNG
# 1 | WBC | 4 – 10 G/L
# 2 | LYM | 17% – 48%hoặc 1 – 5 G/L
# 3 | NEU | 43% – 76 %hoặc 2 – 8 G/L
# 4 | MONO | 4% – 8%hoặc 0,2 – 1,5 G/L
# 5 | EOS | 2% – 4%hoặc 0,1 – 0,7 G/L
# 6 | BASO | 0% – 1%hoặc 0.01 – 0,25 G/L
# 7 | RBC | – Nam: 4,5 – 5,8 T/L– Nữ: 3,9 – 5,2 T/L
# 8 | HGB | – Nam: 130 – 180 g/L– Nữ: 120 – 165 g/L
# 9 | HCT | – Nam 0,39 – 0,49 L/L– Nữ: 0,33 – 0,43 L/L
# 10 | MCV | 85 – 95 fL
# 11 | MCH | 28 – 32 pg
# 12 | MCHC | 320 – 360 g/L
# 13 | RDW | 11% – 15%
# 14 | PLT | 150 – 400 G/L
# 15 | PCT | 0,016 – 0,036 L/L
# 16 | PDW | 11% – 15%
# 17 | MPV | 5 – 8 fL
# 18 | P-LCR | 0,13 – 0,43% hoặc 150 đến 500 Giga/L

# %%
table_text = "Table:\n" + "\n".join([" | ".join(row) for row in table_rows])
result = llm.analyze(table_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 table_text = "Table:\n" + "\n".join([" | ".join(row) for row in table_rows])
#       2 result = llm.analyze(table_text)
#
# NameError: name 'table_rows' is not defined

# %%
nodes
# Out:
# [TextNode(id_='5dbcccd1-61c5-46fa-b567-205532ca9a61', embedding=None, metadata={'file_name': 'super_secret_document.txt', 'category': 'Chỉ số cơ thể', 'author': 'Nguyễn Thị Ngọc'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=['file_name'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='8fcbe4f3-8327-4840-9fe7-158b23f1e341', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_name': 'super_secret_document.txt', 'category': 'Chỉ số cơ thể', 'author': 'Nguyễn Thị Ngọc'}, hash='4aa4dab445afa1bff83f429e0668b5c0ea7b2137e05f7f0cce5b3f5f5b60e9ff'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='699fa345-779e-4bb5-a043-5a516fb5e79f', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='ccea60665919b0fe0e6b2fbf7f005a6ae00223ef0738b33db07fac7e9957cde9')}, metadata_template='{key}=>{value}', metadata_separator='::', text='Metadata: \n-----\nContent: # Các chỉ số khối lượng cơ thể gồm những gì?\n\n[ ![Nguyễn Thị Ngọc](/static/uploads/thumbnail_NG
# ...

# %%
print(os.environ["OPENAI_API_KEY"])
# Out:
# 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

# %%
print(
    "The Embedding model sees this: \n",
    document.get_content(metadata_mode=MetadataMode.EMBED),
)
# Out:
# The Embedding model sees this:
#  Metadata: file_name=>super_secret_document.txt::category=>Chỉ số cơ thể::author=>Nguyễn Thị Ngọc
# -----
# Content: # Các chỉ số khối lượng cơ thể gồm những gì?
#
# [ ![Nguyễn Thị Ngọc](/static/uploads/thumbnail_NGUYEN_THI_NGOC_1f0bf3997e.jpg)
# ](/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi)
#
# Thạc sĩ, Bác sĩ chuyên khoa II,
#
# [Nguyễn Thị Ngọc](/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi)
#
# **Bài viết được tư vấn chuyên môn bởi Thạc sĩ, Bác sĩ Nguyễn Thị Ngọc - Bác sĩ
# Nội tổng quát - Nội tiết -** [**Khoa Khám bệnh & Nội khoa - Bệnh viện Đa khoa
# Quốc tế Vinmec Central Park**](https://www.vinmec.com/vie/bai-viet/kham-suc-
# khoe-tong-quat-nu-la-kham-nhung-gi-vi)**.**
#
# **Các chỉ số khối lượng cơ thể giúp đánh giá tỷ lệ các thành phần cơ thể, qua
# đó phản ánh tình trạng sức khỏe cũng như sự thay đổi của cơ thể khi bạn đang
# ăn kiêng hoặc luyện tập các môn thể thao. Các chỉ số khối lượng cơ thể gồm các
# ...

# %%
from concurrent.futures import ThreadPoolExecutor

def extract_metadata():
    llm = OpenAI(model="gpt-3.5-turbo", temperature=0.1)
    documents = SimpleDirectoryReader("Data").load_data()

    # Useful when dealing w/large docs. Allows for more efficient processing. Also ensures the splitting process respects
    # token boundaries. 
    text_splitter = TokenTextSplitter(separator=" ", chunk_size=1024, chunk_overlap=128)
    
    metadata_extractor = MetadataExtractor(
      extractors=[
            TitleExtractor(nodes=5, llm=llm),
            KeywordExtractor(keywords=2, llm=llm),
      ])

    node_parser = SimpleNodeParser(
      text_splitter=text_splitter, metadata_extractor=metadata_extractor)

    # Use ThreadPoolExecutor to process multiple documents simultaneously
    with ThreadPoolExecutor() as executor:
        nodes = list(executor.map(node_parser.get_nodes_from_documents, documents))

    print(nodes[0].metadata)
    
    # Create a vector store
    service_context = ServiceContext.from_defaults(llm=llm)

    vector_index = VectorStoreIndex(nodes, service_context=service_context, show_progress=True)
    
    kg_index = KnowledgeGraphIndex(nodes, max_tiplets_per_chunk=4, service_context=service_context,
                                             show_progress=True)
    
    return kg_index, vector_index

# %%
nodes

# %%
document
# Out:
# Document(id_='297a411c-d5b5-4429-ae1d-abd8c0b754ee', embedding=None, metadata={'title': 'Sample Article', 'author': 'John Doe', 'date': '2025-01-15', 'tags': ['example', 'html', 'markdown']}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='# Các chỉ số khối lượng cơ thể gồm những gì?\n\n[ ![Nguyễn Thị Ngọc](/static/uploads/thumbnail_NGUYEN_THI_NGOC_1f0bf3997e.jpg)\n](/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi)\n\nThạc sĩ, Bác sĩ chuyên khoa II,\n\n[Nguyễn Thị Ngọc](/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi)\n\n**Bài viết được tư vấn chuyên môn bởi Thạc sĩ, Bác sĩ Nguyễn Thị Ngọc - Bác sĩ\nNội tổng quát - Nội tiết -** [**Khoa Khám bệnh & Nội khoa - Bệnh viện Đa khoa\nQuốc tế Vinmec Central Park**](https://www.vinmec.com/vie/bai-viet/kham-suc-\nkhoe-tong-quat-nu-la-kham-nhung-gi-vi)**.**\n\n**Các chỉ số khối lượng cơ thể giú
# ...

# %%
from markdownify import MarkdownConverter
from markdownify import markdownify as md
md(str(combined_div))
# Out:
# '\n\nCác chỉ số khối lượng cơ thể gồm những gì?\n==========================================\n\n\n[![Nguyễn Thị Ngọc](/static/uploads/thumbnail_NGUYEN_THI_NGOC_1f0bf3997e.jpg)](/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi)\n\nThạc sĩ, Bác sĩ chuyên khoa II,\n\n[Nguyễn Thị Ngọc](/vie/chuyen-gia-y-te/nguyen-thi-ngoc-51360-vi)\n\n\n\n\n\n\n**Bài viết được tư vấn chuyên môn bởi Thạc sĩ, Bác sĩ Nguyễn Thị Ngọc - Bác sĩ Nội tổng quát - Nội tiết -** [**Khoa Khám bệnh & Nội khoa - Bệnh viện Đa khoa Quốc tế Vinmec Central Park**](https://www.vinmec.com/vie/bai-viet/kham-suc-khoe-tong-quat-nu-la-kham-nhung-gi-vi)**.** \n\n\n**Các chỉ số khối lượng cơ thể giúp đánh giá tỷ lệ các thành phần cơ thể, qua đó phản ánh tình trạng sức khỏe cũng như sự thay đổi của cơ thể khi bạn đang ăn kiêng hoặc luyện tập các môn thể thao. Các chỉ số khối lượng cơ thể gồm các chỉ số cơ bản như khối lượng cơ thể, chiều cao, chỉ số BMI, bề dày lớp mỡ dưới da,...**\n\n1. Chỉ số khối lượng cơ thể\n----------------------
# ...

# %%
from llama_index.core import Document, VectorStoreIndex, SimpleDirectoryReader
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.ingestion import IngestionPipeline
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI
from llama_index.core.query_engine import CustomQueryEngine
from llama_index.core.response_synthesizers import BaseSynthesizer
from llama_index.core import get_response_synthesizer
from pathlib import Path

# %%
from llama_index.core.node_parser import (
    SentenceSplitter,
    SemanticSplitterNodeParser,
)

splitter = SemanticSplitterNodeParser(
    buffer_size=7, breakpoint_percentile_threshold=50, embed_model=Settings.embed_model
)

nodes = splitter.get_nodes_from_documents(documents)
print(f"Type: {type(nodes)}")
if isinstance(nodes, list):
    print(f"Length: {len(nodes)}")

# %%
pip install unstructured lxml llama_index
# Out:
# ...
#
# ...
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached langdetect-1.0.9-py3-none-any.whl
# ...
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------- ---------------- 1.0/1.8 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 8.7 MB/s eta 0:00:00
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# ...
#    ---------------------------------------- 0.0/590.6 kB ? eta -:--:--
#    ---------------------------------------- 590.6/590.6 kB 7.0 MB/s eta 0:00:00
# ...
# Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# ...

# %%
from pathlib import Path
from llama_index.readers.file.html.base import HTMLTagReader
from llama_index.core.node_parser.relational.unstructured_element import UnstructuredElementNodeParser
from llama_index.core.schema import Document

def load_html_directory(directory_path: str, tag: str = "section", ignore_no_id: bool = False):
    html_reader = HTMLTagReader(tag=tag, ignore_no_id=ignore_no_id)
    node_parser = UnstructuredElementNodeParser()
    documents = []

    directory = Path(directory_path)
    for html_file in directory.glob("*.html"):
        print(html_file)
        docs = html_reader.load_data(html_file)
        print(docs)
        for doc in docs:
            document = Document(text=doc.text, metadata=doc.metadata)  # Pass the text and metadata attributes
            nodes = node_parser.get_nodes_from_documents([document])
            documents.extend(nodes)

    return documents

# Example usage
directory_path = "C:/Users/mt200/OneDrive/Desktop/AI_egineering/FinalBlogChatbot/chatbot-backend/src/data"
documents = load_html_directory(directory_path, tag="section", ignore_no_id=False)
# Out:
# C:\Users\mt200\OneDrive\Desktop\AI_egineering\FinalBlogChatbot\chatbot-backend\src\data\combined_content.html
# []

# %%
documents
# Out:
# []

# %%
import weaviate
# cloud
cluster_url = "https://wly3tkm2tkewvzycwne6fa.c0.asia-southeast1.gcp.weaviate.cloud"
api_key = "ruGxCkA145k9qWxpoycebKHeLGxc9vtCnLWZ"

client = weaviate.connect_to_wcs(
    cluster_url=cluster_url,
    auth_credentials=weaviate.auth.AuthApiKey(api_key),
)

# %%
from llama_index.vector_stores.weaviate import WeaviateVectorStore
from llama_index.core import VectorStoreIndex, StorageContext

# construct vector store
vector_store = WeaviateVectorStore(weaviate_client = client, index_name="Dinh_duong", text_key="content")

# setting up the storage for the embeddings
storage_context = StorageContext.from_defaults(vector_store = vector_store)

# set up the index
index = VectorStoreIndex(nodes, storage_context = storage_context)

# %%
collection = client.collections.get("Dinh_duong")

# %%
from llama_index.core import Document, VectorStoreIndex, SimpleDirectoryReader
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.ingestion import IngestionPipeline
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI
from llama_index.core.query_engine import CustomQueryEngine
from llama_index.core.response_synthesizers import BaseSynthesizer
from llama_index.core import get_response_synthesizer
from pathlib import Path

# Step 1: Load your data into Documents
loader = SimpleDirectoryReader(input_dir="./data")
documents = loader.load_data()

# Step 2: Create the pipeline with transformations
pipeline = IngestionPipeline(
    transformations=[
        SentenceSplitter(),
    ]
)
nodes = pipeline.run(documents=documents, show_progress=True)

# Step 3: Index your data
embed_model = OpenAIEmbedding()
index = VectorStoreIndex(nodes=nodes, embed_model=embed_model)

# Step 4: Configure the retriever
retriever = VectorIndexRetriever(index=index, similarity_top_k=10)

# Step 5: Define a Custom Query Engine
class RAGQueryEngine(CustomQueryEngine):
    """RAG Query Engine."""

    retriever: BaseRetriever
    response_synthesizer: BaseSynthesizer

    def custom_query(self, query_str: str):
        nodes = self.retriever.retrieve(query_str)
        response_obj = self.response_synthesizer.synthesize(query_str, nodes)
        return response_obj

# Step 6: Configure the Query Engine
synthesizer = get_response_synthesizer(response_mode="compact")

query_engine = RAGQueryEngine(
    retriever=retriever, response_synthesizer=synthesizer
)

# Step 7: Query the index
query = "How tall is the smallest penguin?"
response = query_engine.query(query)

print(response)
